# %% [markdown]
# <a href="https://colab.research.google.com/github/SundasKhanT/notbooks_for_urdu/blob/main/Bloom560m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets scikit-learn torch --quiet

# %%
from datasets import load_dataset
dataset = load_dataset("AhmadMustafa/Urdu-Instruct-News-Category-Classification")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/105M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/11.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/100674 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/11187 [00:00<?, ? examples/s]

# %%
import torch

# Empty the GPU cache
torch.cuda.empty_cache()

# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-560m")
bloom_560m_model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-560m")

# Move the model to GPU with half-precision
bloom_560m_model.half().to("cuda")
# Out:
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# BloomForCausalLM(
#   (transformer): BloomModel(
#     (word_embeddings): Embedding(250880, 1024)
#     (word_embeddings_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (h): ModuleList(
#       (0-23): 24 x BloomBlock(
#         (input_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (self_attention): BloomAttention(
#           (query_key_value): Linear(in_features=1024, out_features=3072, bias=True)
#           (dense): Linear(in_features=1024, out_features=1024, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (post_attention_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): BloomMLP(
#           (dense_h_to_4h): Linear(in_features=1024, out_features=4096, bias=True)
#           (gelu_impl): BloomGelu()
#           (dense_4h_to_h): Linear(in_features=4096, out_features=1024, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=250880, bias=False)
# )

# %%
def get_bloom_560m_output(prompt = "", max_new_tokens = 128):
    urdu_inputs = tokenizer.encode(prompt, return_tensors="pt")
    urdu_inputs = urdu_inputs.to("cuda")  # Move the inputs to the GPU (if available)
    urdu_outputs = bloom_560m_model.generate(urdu_inputs, max_new_tokens = max_new_tokens)

    output = tokenizer.decode(urdu_outputs[0])
    cleaned_output = output.replace("<pad>", "").replace("</s>", "").strip()

    prompt_response = "" + cleaned_output

    return prompt_response

# %%
get_bloom_560m_output("پاکستان کے تین مشہور شعراء کے نام بتائیں")
# Out:
# 'پاکستان کے تین مشہور شعراء کے نام بتائیں گے۔'

# %%
torch.cuda.empty_cache()

# %%
import pandas as pd
from datasets import load_dataset

# Load the dataset
dataset = load_dataset('AhmadMustafa/Urdu-Instruct-News-Category-Classification')

# Check available splits
print(dataset)  # Shows all available splits like 'train', 'test', 'validation', etc.

# Convert to pandas dataframe (adjust split name if needed)
df = dataset['test'].to_pandas()  # or 'test_2' if it exists

# Display the first rows
df.head()
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['inputs', 'targets', 'template_id', 'template_lang'],
#         num_rows: 100674
#     })
#     test: Dataset({
#         features: ['inputs', 'targets', 'template_id', 'template_lang'],
#         num_rows: 11187
#     })
# })
#                                               inputs  \
# 0  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 1  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 2  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 3  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 4  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
#
#                                              targets  template_id  \
# 0           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            2
# 1           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 2  یہ دی گی خبریں "سائنس اور ٹیکنالوجی" سے تعلق ر...            2
# 3           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 4           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
#
#   template_lang
# 0         [urd]
# 1         [urd]
# 2         [urd]
# 3         [urd]
# 4         [urd]

# %%
zero_shot = """
آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔
آپ کا کام اس آرٹیکل کو اس کے مواد کے مطابق پہلے سے طے شدہ زمرے/حصوں میں تقسیم کرنا ہے۔

پہلے سے طے شدہ زمرے/حصے یہ ہیں:
۱. پاکستان
۲. کھیل
۳. ٹیکنالوجی
۴. تفریح
۵. بین الاقوامی
۶. معیشت
۷. طرز زندگی
۸. رائے
۹. تعلیم
"""

# %%
three_shot = """
آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔
آپ کا کام اس آرٹیکل کو اس کے مواد کے مطابق پہلے سے طے شدہ زمرے/حصوں میں تقسیم کرنا ہے۔

پہلے سے طے شدہ زمرے/حصے یہ ہیں:
۱. پاکستان
۲. کھیل
۳. ٹیکنالوجی
۴. تفریح
۵. بین الاقوامی
۶. معیشت
۷. طرز زندگی
۸. رائے
۹. تعلیم

### مثال ۱
آرٹیکل:
'اسلام آباد میں آج نیشنل ہاکی چیمپیئن شپ کے فائنل میں پاکستان ٹیم نے بھارت کو شکست دی۔'
پریڈکٹڈ زمرہ: 'کھیل'

### مثال ۲
آرٹیکل:
'وفاقی حکومت نے نئی معاشی پالیسی کا اعلان کیا ہے جس سے چھوٹے کاروباری حضرات مستفید ہوں گے۔'
پریڈکٹڈ زمرہ: 'معیشت'

### مثال ۳
آرٹیکل:
'نئی موبائل ایپلیکیشن نے صارفین کو اپنے فون سے ہی آن لائن کلاسز لینے کی سہولت دی۔'
پریڈکٹڈ زمرہ: 'ٹیکنالوجی'

### آپ کا کام:
آرٹیکل: "{article_text}"
پریڈکٹڈ زمرہ:
"""

# %%
chain_of_thought_urdu_news = """
آپ کو ایک اردو نیوز آرٹیکل کا ڈیٹاسیٹ دیا گیا ہے۔ آپ کا کام ہر آرٹیکل کو اس کے مواد کے مطابق پہلے سے طے شدہ زمروں/حصوں میں سے ایک میں درجہ بندی کرنا ہے۔

پہلے سے طے شدہ زمرے/حصے ہیں:
۱. پاکستان
۲. کھیل
۳. ٹیکنالوجی
۴. تفریح
۵. بین الاقوامی
۶. معیشت
۷. طرز زندگی
۸. رائے
۹. تعلیم

### غور و فکر کے مراحل:

### مرحلہ ۱: آرٹیکل کا مواد پڑھیں اور سمجھیں
آرٹیکل کے جملے اور بنیادی موضوع کو پڑھیں، اور اس کی نوعیت کا اندازہ لگائیں (مثلاً خبروں کا واقعہ، کھیل، ٹیکنالوجی، تفریح، بین الاقوامی، معیشت، طرز زندگی، رائے یا تعلیم)۔

### مرحلہ ۲: بنیادی تھیم کا تعین
آرٹیکل کے اہم موضوع یا تھیم کا فیصلہ کریں۔ یہ عنوان اور پہلے چند جملے پڑھ کر سمجھا جا سکتا ہے۔

### مرحلہ ۳: زمرے/حصے سے ملاپ
آرٹیکل کے مرکزی تھیم کے مطابق مناسب زمرہ منتخب کریں۔

### مثال ۱
آرٹیکل:
'گزشتہ رات لاہور میں کرکٹ کے ایک میچ کے دوران ٹیم نے شاندار کارکردگی دکھائی۔'

#### سوچ:
- بنیادی مواد: لاہور میں کرکٹ میچ
- مرکزی تھیم: کھیل
- زمرہ/حصے سے ملاپ: کھیل

پریڈکٹیڈ زمرہ: 'کھیل'

### مثال ۲
آرٹیکل:
'حکومت نے نئے تعلیمی نصاب کے نفاذ کا اعلان کیا ہے تاکہ معیار تعلیم بہتر ہو۔'

#### سوچ:
- بنیادی مواد: تعلیمی نصاب اور معیار تعلیم
- مرکزی تھیم: تعلیم
- زمرہ/حصے سے ملاپ: تعلیم

پریڈکٹیڈ زمرہ: 'تعلیم'

### مثال ۳
آرٹیکل:
'نئی سمارٹ فون ٹیکنالوجی نے موبائل صارفین کے لیے کئی نئے فیچرز متعارف کرائے۔'

#### سوچ:
- بنیادی مواد: سمارٹ فون اور نئے فیچرز
- مرکزی تھیم: ٹیکنالوجی
- زمرہ/حصے سے ملاپ: ٹیکنالوجی

پریڈکٹیڈ زمرہ: 'ٹیکنالوجی'

### آپ کا کام:
آرٹیکل: "{article_text}"
پریڈکٹیڈ زمرہ:
"""

# %%
category_translation = {
    'pakistan': 'پاکستان',
    'sports': 'کھیل',
    'technology': 'ٹیکنالوجی',
    'entertainment': 'تفریح',
    'international': 'بین الاقوامی',
    'economy': 'معیشت',
    'lifestyle': 'طرزِ زندگی',
    'opinion': 'رائے',
    'education': 'تعلیم'
}

# %%
import time
from tqdm.notebook import tqdm
import pandas as pd

# Ensure 'predicted_category' column exists
df['predicted_category'] = None

# Limit to first 100 rows
df_subset = df.iloc[:100].copy()

# Try to load progress from previous Parquet file
try:
    df_progress = pd.read_parquet('bloom_560m_zs_classification_results.parquet')
    last_idx = df_progress['predicted_category'].last_valid_index()
    if last_idx is not None and last_idx < 100:
        start_index = last_idx + 1
    else:
        start_index = 0
except (FileNotFoundError, ValueError):
    df_progress = df_subset.copy()
    start_index = 0

# Loop over dataset
for i, row in tqdm(df_subset.iloc[start_index:].iterrows(), initial=start_index, total=len(df_subset) - start_index):
    news = row['inputs']   # Column with Urdu text
    label = row['targets'] # Column with actual label
    label_bn = label       # No translation needed for Urdu

    # Prepare prompt like the Bengali version
    prompt_input = zero_shot + " مضمون کا مواد: " + news + "\nپیش گوئی شدہ زمرہ:"

    try:
        df_subset.at[i, 'predicted_category'] = get_bloom_560m_output(prompt_input, max_new_tokens=256)
    except Exception as e:
        print(f"Error at index {i}: {e}")
        time.sleep(5)

    # Save progress every 100 rows
    if (i + 1) % 100 == 0:
        df_subset.to_parquet('bloom_560m_zs_classification_results.parquet')

# Save final results
df_subset.to_parquet('bloom_560m_zs_classification_results.parquet')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
zs_results = pd.read_parquet("bloom_560m_zs_classification_results.parquet")
zs_results.head()
# Out:
#                                               inputs  \
# 0  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 1  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 2  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 3  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 4  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
#
#                                              targets  template_id  \
# 0           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            2
# 1           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 2  یہ دی گی خبریں "سائنس اور ٹیکنالوجی" سے تعلق ر...            2
# 3           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 4           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
#
#   template_lang                                 predicted_category
# 0         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 1         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 2         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 3         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 4         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...

# %%
zs_results.tail()
# Out:
#                                                inputs  \
# 95  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 96  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 97  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 98  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 99  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
#
#                                               targets  template_id  \
# 95            یہ دی گی خبریں "کھیل" سے تعلق رکھتی ہیں            2
# 96           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 97           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 98           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            2
# 99  یہ دی گی خبریں "کاروبار و معیشت" سے تعلق رکھتی...            2
#
#    template_lang                                 predicted_category
# 95         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 96         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 97         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 98         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 99         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...

# %%
import time
from tqdm.notebook import tqdm

# Ensure 'predicted_category' column exists
df['predicted_category'] = None

# Use only the first 100 rows
df_subset = df.iloc[:100].copy()

# Try to load progress from previous Parquet file
try:
    df_progress = pd.read_parquet('bloom_560m_ts_classification_results.parquet')
    last_idx = df_progress['predicted_category'].last_valid_index()
    start_index = last_idx + 1 if last_idx is not None else 0
except (FileNotFoundError, ValueError):
    df_progress = df_subset.copy()
    start_index = 0

# Loop over the subset
for i, row in tqdm(df_subset.iloc[start_index:].iterrows(), initial=start_index, total=len(df_subset) - start_index):
    news = row['inputs'] # Corrected column name to 'inputs'
    label = row['targets'] # Corrected column name to 'targets'
    label_urdu = category_translation.get(label, label)  # Translated label if available

    prompt_input = three_shot + " مضمون کا مواد: " + news + "\nپیش گوئی شدہ زمرہ:"

    try:
        df_subset.at[i, 'predicted_category'] = get_bloom_560m_output(prompt_input, max_new_tokens=128)
    except Exception as e:
        print(f"Error at index {i}: {e}")
        time.sleep(5)

    # Save progress every 50 rows (or any interval)
    if (i + 1) % 50 == 0:
        df_subset.to_parquet('bloom_560m_ts_classification_results.parquet')

# Save final results
df_subset.to_parquet('bloom_560m_ts_classification_results.parquet')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
ts_results = pd.read_parquet("bloom_560m_ts_classification_results.parquet")
ts_results.head()
# Out:
#                                               inputs  \
# 0  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 1  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 2  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 3  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 4  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
#
#                                              targets  template_id  \
# 0           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            2
# 1           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 2  یہ دی گی خبریں "سائنس اور ٹیکنالوجی" سے تعلق ر...            2
# 3           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 4           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
#
#   template_lang                                 predicted_category
# 0         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 1         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 2         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 3         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...
# 4         [urd]  آپ کو ایک اردو نیوز آرٹیکل دیا گیا ہے۔\nآپ کا ...

# %%
import time
from tqdm.notebook import tqdm
import pandas as pd

# Ensure 'predicted_category' column exists
df['predicted_category'] = None

# Use only the first 100 rows
df_subset = df.iloc[:100].copy()

# Try to load progress from previous Parquet file
try:
    df_progress = pd.read_parquet('bloom_560m_cot_classification_results.parquet')
    last_idx = df_progress['predicted_category'].last_valid_index()
    start_index = last_idx + 1 if last_idx is not None else 0
except (FileNotFoundError, ValueError):
    df_progress = df_subset.copy()
    start_index = 0

# Loop over the subset
for i, row in tqdm(df_subset.iloc[start_index:].iterrows(), initial=start_index, total=len(df_subset) - start_index):
    news = row['inputs']   # Column with Urdu text
    label = row['targets'] # Column with actual label
    label_bn = label       # No translation needed for Urdu

    # Prepare prompt for CoT classification
    prompt_input = chain_of_thought_urdu_news + " مضمون کا مواد: " + news

    try:
        df_subset.at[i, 'predicted_category'] = get_bloom_560m_output(prompt_input, max_new_tokens=256)
    except Exception as e:
        print(f"Error at index {i}: {e}")
        time.sleep(5)

    # Save progress every 50 rows
    if (i + 1) % 50 == 0:
        df_subset.to_parquet('bloom_560m_cot_classification_results.parquet')

# Save final results
df_subset.to_parquet('bloom_560m_cot_classification_results.parquet')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
cot_results = pd.read_parquet("bloom_560m_cot_classification_results.parquet")
cot_results.tail()
# Out:
#                                                inputs  \
# 95  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 96  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 97  اس  پیراگراف (خبروں) کو مندرجہ ذیل درجوں (کیٹگ...
# 98  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
# 99  دیے گی خبروں کو ایک لفظ یا درجہ (کیٹگری) میں ب...
#
#                                               targets  template_id  \
# 95            یہ دی گی خبریں "کھیل" سے تعلق رکھتی ہیں            2
# 96           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 97           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            1
# 98           یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں            2
# 99  یہ دی گی خبریں "کاروبار و معیشت" سے تعلق رکھتی...            2
#
#    template_lang                                 predicted_category
# 95         [urd]  آپ کو ایک اردو نیوز آرٹیکل کا ڈیٹاسیٹ دیا گیا ...
# 96         [urd]  آپ کو ایک اردو نیوز آرٹیکل کا ڈیٹاسیٹ دیا گیا ...
# 97         [urd]  آپ کو ایک اردو نیوز آرٹیکل کا ڈیٹاسیٹ دیا گیا ...
# 98         [urd]  آپ کو ایک اردو نیوز آرٹیکل کا ڈیٹاسیٹ دیا گیا ...
# 99         [urd]  آپ کو ایک اردو نیوز آرٹیکل کا ڈیٹاسیٹ دیا گیا ...

# %%
def clean_predicted_category(text, category_translation):
    # Check if the text is None
    if text is None:
        return ""

    # Check if any category is directly present in the prediction string
    for category in category_translation.values():
        if category in text:
            return category

    # If no direct match, extract the text within ** ** and remove spaces
    import re
    match = re.search(r'\*\*([^*]*)\*\*', text)
    if match:
        cleaned_text = match.group(1).replace(" ", "")
        # Check if cleaned text matches any category in Bangla
        for category in category_translation.values():
            if cleaned_text == category:
                return category

    # If no match found, return None
    return None

# %%
clean_predicted_category("یہ مضمون تعلیم کے زمرے میں آتا ہے۔ \n\n...", category_translation)
# Out:
# 'تعلیم'

# %%
clean_predicted_category("پیش گوئی شدہ زمرہ: **کھیل** \n\nیہ مضمون.....", category_translation)
# Out:
# 'کھیل'

# %%
clean_predicted_category(None, category_translation)
# Out:
# ''

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from sklearn.preprocessing import LabelBinarizer


def evaluate_classification(df):
    # The 'targets' column contains full phrases like 'یہ دی گی خبریں "تفریح" سے تعلق رکھتی ہیں'.
    # We need to extract the actual category name from 'targets' first.
    import re
    def extract_category_from_target(target_string):
        match = re.search(r'"([^"]+)"', target_string)
        if match:
            return match.group(1)
        return None

    df['actual_category_name'] = df['targets'].apply(extract_category_from_target)

    # Clean the predicted categories
    df['cleaned_predicted_category'] = df['predicted_category'].apply(clean_predicted_category, args=(category_translation,))

    # Replace None values with an incorrect label to be treated as wrong predictions
    df['cleaned_predicted_category'] = df['cleaned_predicted_category'].fillna('wrong_prediction')

    # Calculate metrics
    # Use the extracted actual_category_name for y_true
    y_true = df['actual_category_name']
    y_pred = df['cleaned_predicted_category']

    # Filter out rows where actual_category_name is None, as these cannot be evaluated meaningfully
    valid_indices = y_true.notna()
    y_true = y_true[valid_indices]
    y_pred = y_pred[valid_indices]

    # If no valid data remains after filtering, return default metrics
    if y_true.empty or len(y_true.unique()) < 2:
        return {
            'accuracy': 0.0,
            'precision': 0.0,
            'recall': 0.0,
            'f1_score': 0.0,
            'auc_roc': 0.0,
            'log_loss': 0.0
        }

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)

    # For AUC-ROC and Log Loss, we need to binarize the labels
    lb = LabelBinarizer()
    # Ensure all labels in y_true and y_pred are seen by LabelBinarizer fit
    all_labels = pd.concat([y_true, y_pred]).unique()
    lb.fit(all_labels)
    y_true_binarized = lb.transform(y_true)
    y_pred_binarized = lb.transform(y_pred)

    # Ensure y_true_binarized and y_pred_binarized have at least two classes for AUC-ROC
    # and check if it's a multi-class problem
    if y_true_binarized.shape[1] > 1:
        auc_roc = roc_auc_score(y_true_binarized, y_pred_binarized, average='macro', multi_class='ovr')
    else:
        # For binary classification or if only one class is present after filtering
        auc_roc = roc_auc_score(y_true_binarized, y_pred_binarized, average='macro')

    # Log Loss expects probabilities, using binarized hard predictions can lead to issues if any pred is 0 or 1 and actual is different.
    # We'll use predicted_category as class labels, which are then one-hot encoded by LabelBinarizer.transform.
    # If this causes issues, we might need to adjust y_pred_binarized to be smoothed probabilities for log_loss.
    logloss = log_loss(y_true_binarized, y_pred_binarized)

    metrics = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'auc_roc': auc_roc,
        'log_loss': logloss
    }

    return metrics

# %%
zs_df = pd.read_parquet("bloom_560m_zs_classification_results.parquet")
metrics = evaluate_classification(zs_df)
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# accuracy: 0.0000
# precision: 0.0000
# recall: 0.0000
# f1_score: 0.0000
# auc_roc: nan
# log_loss: 36.0437
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %%
ts_df = pd.read_parquet("bloom_560m_ts_classification_results.parquet")
metrics = evaluate_classification(ts_df)
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# accuracy: 0.0000
# precision: 0.0000
# recall: 0.0000
# f1_score: 0.0000
# auc_roc: nan
# log_loss: 36.0437
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %%
cot_df = pd.read_parquet("bloom_560m_cot_classification_results.parquet")
metrics = evaluate_classification(cot_df)
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# accuracy: 0.0000
# precision: 0.0000
# recall: 0.0000
# f1_score: 0.0000
# auc_roc: nan
# log_loss: 36.0437
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(

# %%
# Senitment

from datasets import load_dataset
import pandas as pd

# Load dataset (no second argument needed)
dataset = load_dataset('mteb/IndicSentiment' , 'ur')


# Convert "train" split to pandas
df = dataset["train"].to_pandas()

# Show first rows
df.head()
# Out:
# README.md: 0.00B [00:00, ?B/s]
# test/ur.jsonl.gz:   0%|          | 0.00/236k [00:00<?, ?B/s]
# train/ur.jsonl.gz:   0%|          | 0.00/37.3k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/156 [00:00<?, ? examples/s]
#   GENERIC CATEGORIES    CATEGORY  SUB-CATEGORY            PRODUCT  \
# 0               Home  Appliances  Home theater          Soundbars
# 1            Hobbies       Music  Audio Output         headphones
# 2      Entertainment        Apps  Social Media  Social networking
# 3     Transportation         Air       Flights      International
# 4               Home  Appliances           Fan        Exhaust fan
#
#           BRAND                                            ASPECTS  \
# 0          Boat  Bluetooth/wireless, HDMI, audio output mode, i...
# 1  Zeb Paradise  on-ear, in-ear, wired, bluetooth, earbuds, noi...
# 2     Instagram  find friends, share photos and moments, free m...
# 3      Emirates  luggage allowance, affordable rates, luxury, f...
# 4  Bajaj Maxima  remove moisture/unpleasant odour, air delivery...
#
#               ASPECT COMBO                                     ENGLISH REVIEW  \
# 0                     HDMI  This boat's soundbar is still wire-connectivit...
# 1        Over-ear with mic  Foldable type of microphone with mic and micro...
# 2             daily status  The recently included feature of stories by de...
# 3  Rates Luggage allowance  Rates are competitive, almost always the best ...
# 4            Front Shutter  Looks very big and efficient. But since there ...
#
#       LABEL                                       INDIC REVIEW lang
# 0  Negative  اس بوٹ کا ساؤنڈ بار تمام اسپیکرز کے لیے اب بھی...   ur
# 1  Positive  مائیک اور مائیکرو ایس ڈی کارڈ سلاٹ کے ساتھ قاب...   ur
# 2  Positive  کہانیوں کی حالیہ خصوصیت بطور ڈیفالٹ 24 گھنٹے ت...   ur
# 3  Positive  "قیمتیں مسابقت والی ہیں، مارکیٹ میں تقریباً ہم...   ur
# 4  Negative  بہت بڑا اور موثر ہے۔ لیکن چونکہ سامنے کوئی شٹر...   ur

# %%
zero_shot = """آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جائزے کے جذبات کا تعین کرنا ہے، جو مثبت یا منفی ہو سکتا ہے۔

"""

# %%
three_shot = """آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جائزے کے جذبات کا تعین کرنا ہے، جو مثبت یا منفی ہو سکتا ہے۔

### مثال ۱
### جائزہ:
قیمتیں بہت مناسب ہیں، تقریباً ہمیشہ مارکیٹ میں بہترین۔

### احساس:
مثبت

### مثال ۲
### جائزہ:
آن کال کنیکٹیویٹی اکثر بہت کمزور رہتی ہے۔

### احساس:
منفی

### مثال ۳
### جائزہ:
ہک اور لوپ ڈیزائن بہت آسانی سے سیٹ اپ اور لے جایا جا سکتا ہے۔

### آپ کا کام

"""

# %%
chain_of_thought = """آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جائزے کے جذبات کا تعین کرنا ہے، جو مثبت یا منفی ہو سکتا ہے۔ جذبات کا تعین کرتے وقت درج ذیل مراحل کی پیروی کریں:

### مرحلہ ۱: جائزہ پڑھیں
جائزے کو پڑھیں اور یہ سمجھنے کی کوشش کریں کہ اس میں کیا کہا گیا ہے۔

### مرحلہ ۲: مثبت یا منفی الفاظ کی نشاندہی
جائزے میں استعمال ہونے والے مثبت الفاظ (اچھا، مطمئن، شاندار) یا منفی الفاظ (برا، خراب، کم معیار) کی نشاندہی کریں۔

### مرحلہ ۳: جذبات کا تعین
اگر مثبت الفاظ زیادہ ہوں تو جذبات مثبت، اور اگر منفی الفاظ زیادہ ہوں تو جذبات منفی تصور کریں۔

### مثال ۱
### جائزہ:
قیمتیں مقابلے کی ہیں، تقریباً ہمیشہ مارکیٹ میں بہترین۔

#### سوچنے کا عمل:
- مثبت الفاظ: مقابلے کی، بہترین
- جذبات: مثبت

### جذبات:
مثبت

### مثال ۲
### جائزہ:
آن کال کنیکٹیویٹی اکثر بہت کمزور رہتی ہے۔

#### سوچنے کا عمل:
- منفی الفاظ: اکثر بہت کمزور
- جذبات: منفی

### جذبات:
منفی

### مثال ۳
### جائزہ:
ہک اور لوپ ڈیزائن بہت آسانی سے سیٹ اپ اور لے جایا جا سکتا ہے۔

#### سوچنے کا عمل:
- مثبت الفاظ: بہت آسانی سے سیٹ اپ اور لے جایا جا سکتا ہے
- جذبات: مثبت

### جذبات:
مثبت

### آپ کا کام


"""

# %%
category_translation = {
    'Positive': 'مثبت',
    'Negative': 'منفی',
}

# %%
import time
from tqdm.notebook import tqdm
import pandas as pd

# Use only first 100 rows for faster testing
df_subset = df.iloc[:100].copy()
df_subset['predicted_category'] = None

# Try to load progress if it exists
try:
    df_progress = pd.read_parquet('bloom_560m_zs_urdu_sentiment_results.parquet')
    start_index = df_progress['predicted_category'].last_valid_index() + 1
except (FileNotFoundError, ValueError):
    df_progress = df_subset.copy()
    start_index = 0

# Loop over subset
for i, row in tqdm(df_subset.iloc[start_index:].iterrows(), initial=start_index, total=len(df_subset) - start_index):
    review = row['INDIC REVIEW']  # Urdu review text
    label = row['LABEL']          # Original label
    label_urdu = category_translation.get(label, label)

    # Zero-shot Urdu prompt
    prompt_input = zero_shot + " ###\nجائزہ: " + review + "\n### جذبات:"

    try:
        df_subset.at[i, 'predicted_category'] = get_bloom_560m_output(prompt_input)
    except Exception as e:
        print(f"Error at index {i}: {e}")
        time.sleep(5)

    # Save progress every 50 rows
    if (i + 1) % 50 == 0:
        df_subset.to_parquet('bloom_560m_zs_urdu_sentiment_results.parquet')

# Save final results
df_subset.to_parquet('bloom_560m_zs_urdu_sentiment_results.parquet')
# Out:
#   0%|          | 0/156 [00:00<?, ?it/s]

# %%
zs_results = pd.read_parquet("bloom_560m_zs_urdu_sentiment_results.parquet")
zs_results.tail()
# Out:
#     GENERIC CATEGORIES    CATEGORY      SUB-CATEGORY               PRODUCT  \
# 151               Home  Appliances      Home theater  Home theater systems
# 152               Home  Appliances      Home theater        Tower speakers
# 153    Health/Wellness      Living  Stay/ Experience               Resorts
# 154      Entertainment      Movies            Genres               Tragedy
# 155            Fashion      Beauty         Fragrance  Deodorants for women
#
#                                                  BRAND  \
# 151                                              iKall
# 152                                              iKall
# 153                 Vedic Village Spa Resort (Kolkata)
# 154                                         The Tunnel
# 155  Dove Advanced Care Antiperspirant Deodorant Se...
#
#                                                ASPECTS  \
# 151  Bluetooth, USB &HDMI, Dolby, voice control, sp...
# 152  speaker connectivity, speaker feature, wattage...
# 153  Swimming pool, fitness center, parking, wifi, ...
# 154  serious, storyline, performances, emotional, m...
# 155  alcohol free, skin whitening, odour control, l...
#
#                                 ASPECT COMBO  \
# 151                             Dolby output
# 152                                  Wattage
# 153  Wifi, air conditioning, family friendly
# 154                   Peformances and Moving
# 155                             Long lasting
#
#                                         ENGLISH REVIEW     LABEL  \
# 151  IKall has now launched a new home theater syst...  Positive
# 152  iKall is giving two 500 Watts speakers in its ...  Negative
# 153  The Resort doesn't have wifi, so you have to b...  Negative
# 154  Well directed, & acted, & excellent cinematogr...  Positive
# 155  Its a terrible product!! Works only for a few ...  Negative
#
#                                           INDIC REVIEW lang  \
# 151  آئی کال نے اب ڈولبی آؤٹ پٹ کے ساتھ ایک نیا ہوم...   ur
# 152  آئی کال اپنے ٹاور اسپیکر سیٹ میں دو 500 واٹ کا...   ur
# 153  ریزورٹ میں وائی فائی نہیں ہے، لہذا آپ کو اپنے ...   ur
# 154  عمدہ ہدایت کاری، اور اداکاری، اور عمدہ سنیما گ...   ur
# 155  یہ ایک خوفناک پروڈکٹ ہے!! یہ صرف چند گھنٹوں کے...   ur
#
#                                     predicted_category
# 151  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 152  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 153  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 154  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 155  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...

# %%
import time
from tqdm.notebook import tqdm
import pandas as pd

# Use only first 100 rows for testing
df_subset = df.iloc[:100].copy()
df_subset['predicted_category'] = None

# Try to load progress if it exists
try:
    df_progress = pd.read_parquet('bloom_560m_ts_sentiment_results.parquet')
    start_index = df_progress['predicted_category'].last_valid_index() + 1
except (FileNotFoundError, ValueError):
    df_progress = df_subset.copy()
    start_index = 0

# Loop over the subset
for i, row in tqdm(df_subset.iloc[start_index:].iterrows(), initial=start_index, total=len(df_subset) - start_index):
    review = row['INDIC REVIEW']
    label = row['LABEL']
    label_urdu = category_translation.get(label, label)  # Translate label if needed

    # Three-shot Urdu prompt
    prompt_input = three_shot + " ###\nجائزہ: " + review + "\n### جذبات:"

    try:
        df_subset.at[i, 'predicted_category'] = get_bloom_560m_output(prompt_input, max_new_tokens=256)
    except Exception as e:
        print(f"Error at index {i}: {e}")
        time.sleep(5)

    # Save progress every 50 rows
    if (i + 1) % 50 == 0:
        df_subset.to_parquet('bloom_560m_ts_sentiment_results.parquet')

# Save final results
df_subset.to_parquet('bloom_560m_ts_sentiment_results.parquet')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
ts_results = pd.read_parquet("bloom_560m_ts_sentiment_results.parquet")
ts_results.tail()
# Out:
#    GENERIC CATEGORIES     CATEGORY        SUB-CATEGORY       PRODUCT  \
# 95      Entertainment       Movies              Genres  Family Drama
# 96               Pets         Dogs            Grooming   Deodorizers
# 97            Hobbies        Music         Audio Input    Microphone
# 98            Hobbies  Photography  Camera accessories      Lens cap
# 99            Hobbies  Photography  Camera accessories     Lens case
#
#                         BRAND  \
# 95            The Parent Trap
# 96                  First Pet
# 97  Rhinocables PC microphone
# 98                    Hanumex
# 99                   Digicare
#
#                                               ASPECTS  \
# 95  entertaining, family values, relatable charact...
# 96           ayurvedic, scent, fresh, vet recommended
# 97  frequency response, self-noise, sensitivity, p...
# 98             durability, dust and scratch resistent
# 99  thick material for protection, hook, compatibi...
#
#                                          ASPECT COMBO  \
# 95                              Story-line, melodrama
# 96  provides moisture to irritated, itchy, painful...
# 97                    frequency response, self-noise,
# 98                                         Durability
# 99                      thick material for protection
#
#                                        ENGLISH REVIEW     LABEL  \
# 95  At every scene where the parents appeared they...  Negative
# 96  It is particularly effective in providing mois...  Positive
# 97              quality is terrible,self noise exists  Negative
# 98  Cap is manufactured with cheap quality plastic...  Negative
# 99  Neaprene material coating from outside but no ...  Negative
#
#                                          INDIC REVIEW lang  \
# 95  ہر اس منظر میں جہاں والدین نمودار ہوئے، وہ اس ...   ur
# 96  یہ خاص طور پر چڑچڑاپن، کھجلی اور تکلیف دہ جلدی...   ur
# 97                      معیار خوفناک ہے، شور موجود ہے   ur
# 98  کیپ سستے معیاری پلاسٹک کے مواد سے تیار کی جاتی...   ur
# 99  باہر سے نیوپرین مواد کی کوٹنگ لیکن اندر کوئی ک...   ur
#
#                                    predicted_category
# 95  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 96  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 97  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 98  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 99  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...

# %%
import time
from tqdm.notebook import tqdm
import pandas as pd

# Use only first 100 rows for testing
df_subset = df.iloc[:100].copy()
df_subset['predicted_category'] = None

# Try to load progress if it exists
try:
    df_progress = pd.read_parquet('bloom_560m_cot_sentiment_results.parquet')
    start_index = df_progress['predicted_category'].last_valid_index() + 1
except (FileNotFoundError, ValueError):
    df_progress = df_subset.copy()
    start_index = 0

# Loop over the subset
for i, row in tqdm(df_subset.iloc[start_index:].iterrows(), initial=start_index, total=len(df_subset) - start_index):
    review = row['INDIC REVIEW']
    label = row['LABEL']
    label_urdu = category_translation.get(label, label)  # Translate label if needed

    # CoT Urdu prompt
    prompt_input = chain_of_thought + "\n### جائزہ: " + review

    try:
        df_subset.at[i, 'predicted_category'] = get_bloom_560m_output(prompt_input, max_new_tokens=256)
    except Exception as e:
        print(f"Error at index {i}: {e}")
        time.sleep(5)

    # Save progress every 50 rows
    if (i + 1) % 50 == 0:
        df_subset.to_parquet('bloom_560m_cot_sentiment_results.parquet')

# Save final results
df_subset.to_parquet('bloom_560m_cot_sentiment_results.parquet')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
cot_results = pd.read_parquet("bloom_560m_cot_sentiment_results.parquet")
cot_results.tail()
# Out:
#    GENERIC CATEGORIES     CATEGORY        SUB-CATEGORY       PRODUCT  \
# 95      Entertainment       Movies              Genres  Family Drama
# 96               Pets         Dogs            Grooming   Deodorizers
# 97            Hobbies        Music         Audio Input    Microphone
# 98            Hobbies  Photography  Camera accessories      Lens cap
# 99            Hobbies  Photography  Camera accessories     Lens case
#
#                         BRAND  \
# 95            The Parent Trap
# 96                  First Pet
# 97  Rhinocables PC microphone
# 98                    Hanumex
# 99                   Digicare
#
#                                               ASPECTS  \
# 95  entertaining, family values, relatable charact...
# 96           ayurvedic, scent, fresh, vet recommended
# 97  frequency response, self-noise, sensitivity, p...
# 98             durability, dust and scratch resistent
# 99  thick material for protection, hook, compatibi...
#
#                                          ASPECT COMBO  \
# 95                              Story-line, melodrama
# 96  provides moisture to irritated, itchy, painful...
# 97                    frequency response, self-noise,
# 98                                         Durability
# 99                      thick material for protection
#
#                                        ENGLISH REVIEW     LABEL  \
# 95  At every scene where the parents appeared they...  Negative
# 96  It is particularly effective in providing mois...  Positive
# 97              quality is terrible,self noise exists  Negative
# 98  Cap is manufactured with cheap quality plastic...  Negative
# 99  Neaprene material coating from outside but no ...  Negative
#
#                                          INDIC REVIEW lang  \
# 95  ہر اس منظر میں جہاں والدین نمودار ہوئے، وہ اس ...   ur
# 96  یہ خاص طور پر چڑچڑاپن، کھجلی اور تکلیف دہ جلدی...   ur
# 97                      معیار خوفناک ہے، شور موجود ہے   ur
# 98  کیپ سستے معیاری پلاسٹک کے مواد سے تیار کی جاتی...   ur
# 99  باہر سے نیوپرین مواد کی کوٹنگ لیکن اندر کوئی ک...   ur
#
#                                    predicted_category
# 95  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 96  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 97  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 98  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...
# 99  آپ کو ایک پروڈکٹ کا جائزہ دیا گیا ہے۔ آپ کو جا...

# %%
def clean_predicted_category(text, category_translation):
    if text is None:
        return ""

    # Assuming `text` contains the original prompt + model's generation.
    # The generation for the category should typically appear after the last 'جذبات:' tag.
    import re

    # Find the last occurrence of 'جذبات:' in the text
    last_sentiment_tag_index = text.rfind("جذبات:")
    if last_sentiment_tag_index != -1:
        # Extract the content after the last 'جذبات:'
        potential_category_text = text[last_sentiment_tag_index + len("جذبات:"):].strip()
    else:
        # If 'جذبات:' is not found, consider the entire text for pattern matching
        potential_category_text = text

    # First, check if any category is directly present in the extracted text
    for category_urdu in category_translation.values():
        if category_urdu in potential_category_text:
            return category_urdu

    # If no direct match, check for text within ** ** (e.g., '**مثبت**')
    match = re.search(r'\*\*([^*]*)\*\*', potential_category_text)
    if match:
        cleaned_text = match.group(1).strip() # Extract and strip whitespace
        for category_urdu in category_translation.values():
            if cleaned_text == category_urdu:
                return category_urdu

    # If no category is found or extracted, return an empty string
    return ""

# %%
clean_predicted_category("جذبات: **منفی** \n\nجائزہ میں کہا گیا ہے ...", category_translation)
# Out:
# 'منفی'

# %%
clean_predicted_category("جذبات: **مثبت** \n\nقیمتیں مقابلے کی ہیں...", category_translation)
# Out:
# 'مثبت'

# %%
clean_predicted_category(None, category_translation)
# Out:
# ''

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from sklearn.preprocessing import LabelBinarizer

def update_cleaned_predicted_category(row):
    if pd.isna(row['cleaned_predicted_category']) or row['cleaned_predicted_category'] == '':
        if row['category_ur'] == 'مثبت':
            return 'منفی'
        elif row['category_ur'] == 'منفی':
            return 'مثبت'
    return row['cleaned_predicted_category']

def evaluate_classification(df):
    df['category'] = df['LABEL']
    # Map English category to Urdu
    df['category_ur'] = df['category'].map(category_translation)

    # Clean the predicted categories
    df['cleaned_predicted_category'] = df['predicted_category'].apply(clean_predicted_category, args=(category_translation,))

    # Update the cleaned predicted categories
    for index, row in df.iterrows():
        old_value = row['cleaned_predicted_category']
        if pd.isna(old_value) or old_value == '':
            if row['category_ur'] == 'مثبت':
                new_value = 'منفی'
            elif row['category_ur'] == 'منفی':
                new_value = 'مثبت'
            df.at[index, 'cleaned_predicted_category'] = new_value

    unique_labels = set(df['category_ur'].unique()).union(set(df['cleaned_predicted_category'].unique()))
    if len(unique_labels) > 2:
        raise ValueError(f"Expected binary classification but found multiple labels: {unique_labels}")

    # Calculate metrics
    y_true = df['category_ur']
    y_pred = df['cleaned_predicted_category']

    # Ensure the labels are binary
    lb = LabelBinarizer()
    y_true_binarized = lb.fit_transform(y_true)
    y_pred_binarized = lb.transform(y_pred)

    if len(lb.classes_) != 2:
        raise ValueError(f"Expected binary classification but found these classes: {lb.classes_}")

    pos_label = lb.classes_[1]  # The positive label

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, pos_label=pos_label, average='binary', zero_division=0)
    recall = recall_score(y_true, y_pred, pos_label=pos_label, average='binary', zero_division=0)
    f1 = f1_score(y_true, y_pred, pos_label=pos_label, average='binary', zero_division=0)
    auc_roc = roc_auc_score(y_true_binarized, y_pred_binarized)
    logloss = log_loss(y_true_binarized, y_pred_binarized)

    metrics = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'auc_roc': auc_roc,
        'log_loss': logloss
    }

    return metrics

# %%
zs_df = pd.read_parquet("bloom_560m_zs_urdu_sentiment_results.parquet")
metrics = evaluate_classification(zs_df)
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# accuracy: 0.4808
# precision: 0.0000
# recall: 0.0000
# f1_score: 0.0000
# auc_roc: 0.5000
# log_loss: 18.7150

# %%
ts_df = pd.read_parquet("bloom_560m_ts_sentiment_results.parquet")
metrics = evaluate_classification(ts_df)
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# accuracy: 0.4500
# precision: 0.0000
# recall: 0.0000
# f1_score: 0.0000
# auc_roc: 0.5000
# log_loss: 19.8240

# %%
cot_df = pd.read_parquet("bloom_560m_cot_sentiment_results.parquet")
metrics = evaluate_classification(cot_df)
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# accuracy: 0.4500
# precision: 0.0000
# recall: 0.0000
# f1_score: 0.0000
# auc_roc: 0.5000
# log_loss: 19.8240
